# %%
import bamboolib as bam
df = bam.get_sales_df()
df
# Out:
#                                 region                 country  \
# 0    Central America and the Caribbean                 Grenada
# 1                               Europe                  Greece
# 2                               Europe              Luxembourg
# 3                               Europe                  Latvia
# 4                               Europe          Czech Republic
# ..                                 ...                     ...
# 995                               Asia                 Vietnam
# 996                 Sub-Saharan Africa            Burkina Faso
# 997                             Europe              Luxembourg
# 998  Central America and the Caribbean  Saint Kitts and Nevis
# 999  Central America and the Caribbean                    Cuba
#
#            item_type sales_channel order_prio  order_date   order_id  \
# 0          Baby Food       Offline          C    8/9/2012  987416255
# 1      Personal Care        Online          M    5/2/2010  574704110
# ...
